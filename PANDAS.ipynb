# %%
import pandas as pd
import numpy as np

# %% [markdown]
# multiple way to create data frame.data frame is table like data structure containing rows and columns similar to excel spreadsheet
# #diffrwnt way of creating data frame

# %%
df8=pd.DataFrame(np.arange(0,20).reshape(5,4),index=['row1','row2','row3','row4','row5'],columns=['col1','col2','col2','col2'])
df8
# Out:
#       col1  col2  col2  col2
# row1     0     1     2     3
# row2     4     5     6     7
# row3     8     9    10    11
# row4    12    13    14    15
# row5    16    17    18    19

# %%
df#using  csv or excel
df=pd.read_csv( 'file name.csv')
      #or
df=pd.read_excel( 'file name.xlsx')

# %%
#using dictiory
df1={'day':['mon','tue','yus','wen','fri','sat','sun'],
             'tempreture':[45,76,35,87,67,34,52],
             'windspeed':[4,8,6,9,3,10,7],
             'event':['fun','study','party','fun','study','party','fun']}
df1=pd.DataFrame(df1)
#df1=pd.Series(df1) try it out what happening
df1
# Out:
#    day  tempreture  windspeed  event
# 0  mon          45          4    fun
# 1  tue          76          8  study
# 2  yus          35          6  party
# 3  wen          87          9    fun
# 4  fri          67          3  study
# 5  sat          34         10  party
# 6  sun          52          7    fun

# %%
pd.melt(df1)
# Out:
#       variable  value
# 0          day    mon
# 1          day    tue
# 2          day    yus
# 3          day    wen
# 4          day    fri
# 5          day    sat
# 6          day    sun
# 7   tempreture     45
# 8   tempreture     76
# 9   tempreture     35
# 10  tempreture     87
# 11  tempreture     67
# 12  tempreture     34
# 13  tempreture     52
# 14   windspeed      4
# 15   windspeed      8
# 16   windspeed      6
# 17   windspeed      9
# 18   windspeed      3
# 19   windspeed     10
# 20   windspeed      7
# 21       event    fun
# 22       event  study
# 23       event  party
# 24       event    fun
# 25       event  study
# 26       event  party
# 27       event    fun

# %%
import pandas as pd
df=pd.read_excel('C:\\Users\\dell\\Downloads//Book1.xlsx')
df
# Out:
#    day  tempreture  windspeed  event
# 0  mon          45          4    fun
# 1  tue          76          8  study
# 2  yus          35          6  party
# 3  wen          87          9    fun
# 4  fri          67          3  study
# 5  sat          34         10  party
# 6  sun          52          7    fun

# %%
print(df.tail())
print(df.tail(1))
print(df.head())
df.head(1)
# Out:
#    day  tempreture  windspeed  event
# 2  yus          35          6  party
# 3  wen          87          9    fun
# 4  fri          67          3  study
# 5  sat          34         10  party
# 6  sun          52          7    fun
#    day  tempreture  windspeed event
# 6  sun          52          7   fun
#    day  tempreture  windspeed  event
# 0  mon          45          4    fun
# 1  tue          76          8  study
# 2  yus          35          6  party
# 3  wen          87          9    fun
# 4  fri          67          3  study
#    day  tempreture  windspeed event
# 0  mon          45          4   fun

# %%
list(df.columns)
# Out:
# ['day', 'tempreture', 'windspeed', 'event']

# %%
print(df.describe())
print(df.info())
# Out:
#        tempreture  windspeed
# count    7.000000   7.000000
# mean    56.571429   6.714286
# std     20.582008   2.563480
# min     34.000000   3.000000
# 25%     40.000000   5.000000
# 50%     52.000000   7.000000
# 75%     71.500000   8.500000
# max     87.000000  10.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   day         7 non-null      object
#  1   tempreture  7 non-null      int64
#  2   windspeed   7 non-null      int64
#  3   event       7 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 352.0+ bytes
# None

# %%
df[['event']]#df['event']#df.event
# Out:
#    event
# 0    fun
# 1  study
# 2  party
# 3    fun
# 4  study
# 5  party
# 6    fun

# %%
print(type(df[['event']]))
type(df['event'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# pandas.core.series.Series

# %%
df[['day','windspeed']]
# Out:
#    day  windspeed
# 0  mon          4
# 1  tue          8
# 2  yus          6
# 3  wen          9
# 4  fri          3
# 5  sat         10
# 6  sun          7

# %%
df[df.tempreture==df.tempreture.max()]
# Out:
#    day  tempreture  windspeed event
# 3  wen          87          9   fun

# %%
df[['day','windspeed','tempreture']][df.tempreture==df.tempreture.max()]
# Out:
#    day  windspeed  tempreture
# 3  wen          9          87

# %%
df.tempreture.max()
# Out:
# 87

# %%
df.loc[0] 
#df.loc[[0]]
# Out:
# day           mon
# tempreture     45
# windspeed       4
# event         fun
# Name: 0, dtype: object

# %%
df.loc[1:5]
#df.loc[[1,5]]
# Out:
#     a   b   c
# 1   4   4   6
# 2   7   8   9
# 3  10  11  12

# %%
df[['day']][df['event']=='fun']
# Out:
#    day
# 0  mon
# 3  wen
# 6  sun

# %%
#df.set_index('day',inplace=True)
#df.reset_index(inplace=True)

# %%
df1=pd.read_csv('dirtydata.csv')
df1.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'     -1       148     406.0

# %%
df1['Date']=pd.to_datetime(df1['Date'])
df1
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05     -1       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98        -1     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...

# %%
df1.describe()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      32 non-null     datetime64[ns]
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  32 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3)
# memory usage: 1.4 KB

# %%
df1['Calories']=df1['Calories'].fillna(130)
df1=df1.fillna(method='ffill',axis='index')
df1.tail(15)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 17        60 2020-12-17    100       120     300.0
# 18        45 2020-12-18     -1       112     130.0
# 19        60 2020-12-19    103       123     323.0
# 20        45 2020-12-20     97       125     243.0
# 21        60 2020-12-21    108       131     364.2
# 22        45 2020-12-22    100       119     282.0
# 23        60 2020-12-23    130       101     300.0
# 24        45 2020-12-24    105       132     246.0
# 25        60 2020-12-25    102       126     334.5
# 26        60 2020-12-26    100       120     250.0
# 27        60 2020-12-27     92       118     241.0
# 28        60 2020-12-28    103       132     130.0
# 29        60 2020-12-29    100       132     280.0
# 30        60 2020-12-30    102       129     380.3
# 31        60 2020-12-31     92       115     243.0

# %%
df1.at[22,'Date']='2020/12/22'
#df.loc[22,'Date']='2020/12/22'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 df1.at[22,'Date']='2020/12/22'
# ----> 2 df.loc[22,'Date']='2020/12/22'
#
# NameError: name 'df' is not defined

# %%
df4=df1.dropna()#how='all'

# %% [markdown]
# #concate and merge concept

# %%
df = pd.DataFrame(
[ [4 ,4, 6], 
 [7, 8, 9], 
 [10, 11, 12]], 
index = [1, 2, 3],
columns=['a', 'b', 'c'])

df2 = pd.DataFrame(
[[4, 7, 10],
[5, 8, 11],
[6, 9, 12]], 
index=[1, 2, 3], 
columns=['d', 'e', 'f'])
pd.concat([df,df2],axis=1)
# Out:
#     a   b   c  d  e   f
# 1   4   4   6  4  7  10
# 2   7   8   9  5  8  11
# 3  10  11  12  6  9  12

# %%
df2.drop(columns=['e','f'])
# Out:
#    d
# 1  4
# 2  5
# 3  6

# %%
df2.rename(columns = {'d':'D'})
# Out:
#    D  e   f
# 1  4  7  10
# 2  5  8  11
# 3  6  9  12

# %%
pd.concat([df,df2],axis=1)
# Out:
#     a   b   c  d  e   f
# 1   4   4   6  4  7  10
# 2   7   8   9  5  8  11
# 3  10  11  12  6  9  12

# %%
df2.sort_values('e',ascending=False)
# Out:
#    d  e   f
# 3  6  9  12
# 2  5  8  11
# 1  4  7  10

# %%
df7_stocks=pd.DataFrame({'tickers':['ggogl','wmt','msft'],
                       'price':[856,54,67],
                       'pe':[30.37,45.46,59.87],
                       'eps':[27.8,4.61,2.12]})
df7_weather=pd.DataFrame({'day':['mon','tue','wen'],
                        'tempreture':[32,45,65],
                         'event':['rain','cold','sunny']})

#df7=pd.concat([df7_stocks,df7_weather],ignore_index=True)
#df7=pd.concat([df7_stocks,df7_weather],axis=1)
df7=pd.concat([df7_stocks,df7_weather],keys=['chirag','tannu'],axis=0)


df7
# Out:
#          tickers  price     pe    eps  day  tempreture  event
# chirag 0   ggogl  856.0  30.37  27.80  NaN         NaN    NaN
#        1     wmt   54.0  45.46   4.61  NaN         NaN    NaN
#        2    msft   67.0  59.87   2.12  NaN         NaN    NaN
# tannu  0     NaN    NaN    NaN    NaN  mon        32.0   rain
#        1     NaN    NaN    NaN    NaN  tue        45.0   cold
#        2     NaN    NaN    NaN    NaN  wen        65.0  sunny

# %%
df7=pd.concat([df7_stocks,df7_weather],keys=['chirag','tannu'],axis=1)
df7
# Out:
#    chirag                     tannu
#   tickers price     pe    eps   day tempreture  event
# 0   ggogl   856  30.37  27.80   mon         32   rain
# 1     wmt    54  45.46   4.61   tue         45   cold
# 2    msft    67  59.87   2.12   wen         65  sunny

# %%
df7.loc['tannu']
# Out:
#   tickers  price  pe  eps  day  tempreture  event
# 0     NaN    NaN NaN  NaN  mon        32.0   rain
# 1     NaN    NaN NaN  NaN  tue        45.0   cold
# 2     NaN    NaN NaN  NaN  wen        65.0  sunny

# %%
df8_weather=pd.DataFrame({'day':['mon','tue','wen'],
                        'tempreture':[32,45,65]})
s=pd.Series(['humid','rain','cold'],name='event')
df8=pd.concat([df8_weather,s],axis=1)
df8
# Out:
#    day  tempreture  event
# 0  mon          32  humid
# 1  tue          45   rain
# 2  wen          65   cold

# %%
df8=pd.merge(df8_weather,s)
df8
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Input In [92], in <cell line: 1>()
# ----> 1 df8=pd.merge(df8_weather,s)
#       2 df8
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
# ...

# %%
df10=pd.DataFrame({'tickers':['wmt','msft','ggogl','adani'],
                       'price':[856,54,67,89]})
df9=pd.DataFrame({'tickers':['ggogl','wmt','msft','tata'],
                        'tempreture':[32,45,65,90]})
dft2=pd.merge(df10,df9,on='tickers')
dft2=pd.merge(df10,df9,on='tickers',how='outer')
dft=pd.merge(df10,df9,on='tickers',how='inner')
dft
dft.sort_index(axis=1,ascending=True)
dft.sort_values(by='price',ascending=False)
dft[dft['price']>100]
dft1=dft.copy
print(dft1)
print(dft.interpolate().plot)
dft.interpolate().count()   #df.interpolate(method='time')
dft[dft['price']>100]
# Out:
# <bound method NDFrame.copy of   tickers  price  tempreture
# 0     wmt    856          45
# 1    msft     54          65
# 2   ggogl     67          32>
# ...
#   tickers  price  tempreture
# 0     wmt    856          45

# %%
dft
print(dft.interpolate().plot)

# %%
dft2
# Out:
#   tickers  price  tempreture
# 0     wmt  856.0        45.0
# 1    msft   54.0        65.0
# 2   ggogl   67.0        32.0
# 3   adani   89.0         NaN
# 4    tata    NaN        90.0

# %%
dft2.sum(0,skipna=True)
dft2.mean(0,skipna=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11968\2756595697.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dft2.mean(0,skipna=True)
# price         266.5
# tempreture     58.0
# dtype: float64

# %%
dft2.sum(1,skipna=True)
dft2.mean(1,skipna=True)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11968\768332356.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dft2.sum(1,skipna=True)
# C:\Users\dell\AppData\Local\Temp\ipykernel_11968\768332356.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dft2.mean(1,skipna=True)
# 0    450.5
# 1     59.5
# 2     49.5
# 3     89.0
# 4     90.0
# dtype: float64

# %%
dft=pd.merge(df10,df9,on='tickers',how='inner') #only take common value
dft
# Out:
#   tickers  price  tempreture
# 0     wmt    856          45
# 1    msft     54          65
# 2   ggogl     67          32

# %%
dft=pd.merge(df10,df9,on='tickers',how='left')
dft
# Out:
#   tickers  price  tempreture
# 0     wmt    856        45.0
# 1    msft     54        65.0
# 2   ggogl     67        32.0
# 3   adani     89         NaN

# %%
dft=pd.merge(df10,df9,on='tickers',how='right')
dft
# Out:
#   tickers  price  tempreture
# 0   ggogl   67.0          32
# 1     wmt  856.0          45
# 2    msft   54.0          65
# 3    tata    NaN          90

# %%
dft=pd.concat([df10,df9],axis=1)
dft
# Out:
#   tickers  price tickers  tempreture
# 0     wmt    856   ggogl          32
# 1    msft     54     wmt          45
# 2   ggogl     67    msft          65

# %%
with pd.ExcelWriter('stocks_weather.xlsx') as writer:
    df7_stocks.to_excel(writer,sheet_name='stocks')
    df7_weather.to_excel(writer,sheet_name='weather')

# %%
#df.to_excel('new.xlsx',sheet_name='any',index=False,satartrow=2,startcol=1)

# %%
#missing handling data

# %%
df6=pd.read_excel('C:\\Users\\dell\\Downloads//book2.xlsx')
df6
# Out:
#   tickers            eps  revenue price         people
# 0   googl          27.82       87   845      lany page
# 1     wmt           4.81      484    65           n.a.
# 2   msift             -1       85    78     bill gates
# 3     rsl  not available       50  1034  mukesh ambani
# 4     sdf            5.6       -1  n.a.      elon musk
# 5     scv           11.8       30   324     ratan tata

# %%
df6.duplicated()
df6.drop_duplicates() #keep =last and first
df6.index.drop_duplicates(1) #by index
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3000\110252034.py:3: FutureWarning: In a future version of pandas all arguments of Index.drop_duplicates will be keyword-only.
#   df6.index.drop_duplicates(1) #by index
# RangeIndex(start=0, stop=6, step=1)

# %%
#df=pd.read_excel('C:\\Users\\dell\\Downloads//book2.xlsx',na_values={'eps':['not available'],'revenue':[-1],'price':[-1],'people':['n.a.']})

#df1=pd.read_excel('C:\\Users\\dell\\Downloads//book2.xlsx',na_values=['not available','n.a.','-1',-1])

df1=pd.read_excel('C:\\Users\\dell\\Downloads//book2.xlsx',na_values=['not available','n.a.',-1])
df1=df1.replace({'revenue':-1},np.nan)
df1
# Out:
#   tickers    eps  revenue   price         people
# 0   googl  27.82     87.0   845.0      lany page
# 1     wmt   4.81    484.0    65.0            NaN
# 2   msift    NaN     85.0    78.0     bill gates
# 3     rsl    NaN     50.0  1034.0  mukesh ambani
# 4     sdf   5.60      NaN     NaN      elon musk
# 5     scv  11.80     30.0   324.0     ratan tata

# %%
def convert_people_cell(cell):
    if cell=='n.a.':
        return 'chirag'
    return cell
def convert_price_cell(cell):
    if cell=='n.a.':
        return 'chirag'
    return cell
df5=pd.read_excel('C:\\Users\\dell\\Downloads//book2.xlsx',converters={
       'people':convert_people_cell,
       'price':convert_price_cell
    })
df5
# Out:
#   tickers            eps  revenue   price         people
# 0   googl          27.82       87     845      lany page
# 1     wmt           4.81      484      65         chirag
# 2   msift             -1       85      78     bill gates
# 3     rsl  not available       50    1034  mukesh ambani
# 4     sdf            5.6       -1  chirag      elon musk
# 5     scv           11.8       30     324     ratan tata

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tickers  6 non-null      object
#  1   eps      6 non-null      object
#  2   revenue  6 non-null      int64
#  3   price    6 non-null      object
#  4   people   6 non-null      object
# dtypes: int64(1), object(4)
# memory usage: 368.0+ bytes

# %%
df=pd.read_excel('C:\\Users\\dell\\Downloads//book2.xlsx','Sheet3')
df
# Out:
#          day        tempreture      windspeed  event
# 0 2017-01-01              32 F          6 mph   rain
# 1 2017-01-02             -9999          7 mph  sunny
# 2 2017-01-03              28 C          -9999   snow
# 3 2017-01-04             -9999              7      0
# 4 2017-01-05                32          -9999   rain
# 5 2017-01-06                31              2  sunny
# 6 2017-01-07                34              5      0

# %%
df=df.replace({'tempreture':-9999,'windspeed':-9999,'event':0},np.nan)
df
# Out:
#          day        tempreture      windspeed  event
# 0 2017-01-01              32 F          6 mph   rain
# 1 2017-01-02               NaN          7 mph  sunny
# 2 2017-01-03              28 C            NaN   snow
# 3 2017-01-04               NaN              7    NaN
# 4 2017-01-05                32            NaN   rain
# 5 2017-01-06                31              2  sunny
# 6 2017-01-07                34              5    NaN

# %%
df1=pd.read_excel('C:\\Users\\dell\\Downloads//book2.xlsx','Sheet3',na_values=['-9999',0])
df1.set_index('day',inplace=True)
df1.info()
df1
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 7 entries, 2017-01-01 to 2017-01-07
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tempreture  5 non-null      object
#  1   windspeed   5 non-null      object
#  2   event       5 non-null      object
# dtypes: object(3)
# memory usage: 224.0+ bytes
#                   tempreture      windspeed  event
# day
# 2017-01-01              32 F          6 mph   rain
# 2017-01-02               NaN          7 mph  sunny
# 2017-01-03              28 C            NaN   snow
# 2017-01-04               NaN              7    NaN
# 2017-01-05                32            NaN   rain
# 2017-01-06                31              2  sunny
# 2017-01-07                34              5    NaN

# %%
#df1=df1.fillna(0)
df
# Out:
#          day        tempreture      windspeed  event
# 0 2017-01-01              32 F          6 mph   rain
# 1 2017-01-02               NaN          7 mph  sunny
# 2 2017-01-03              28 C            NaN   snow
# 3 2017-01-04               NaN              7    NaN
# 4 2017-01-05                32            NaN   rain
# 5 2017-01-06                31              2  sunny
# 6 2017-01-07                34              5    NaN

# %%
df1=df1.fillna({'tempreture':0,'windspeed':0,'event':'no event'})
df1
# Out:
#                   tempreture      windspeed     event
# day
# 2017-01-01              32 F          6 mph      rain
# 2017-01-02                 0          7 mph     sunny
# 2017-01-03              28 C              0      snow
# 2017-01-04                 0              7  no event
# 2017-01-05                32              0      rain
# 2017-01-06                31              2     sunny
# 2017-01-07                34              5  no event

# %%
new_df1=df.replace({'tempreture':'[A-Za-z]','windspeed':'[a-z]'},'',regex=True)
new_df1
# Out:
#          day       tempreture   windspeed  event
# 0 2017-01-01              32           6    rain
# 1 2017-01-02              NaN          7   sunny
# 2 2017-01-03              28          NaN   snow
# 3 2017-01-04              NaN           7    NaN
# 4 2017-01-05               32         NaN   rain
# 5 2017-01-06               31           2  sunny
# 6 2017-01-07               34           5    NaN

# %%
df1=new_df1.fillna(method='bfill',axis='index') #instead of index u may use columns #ffill
df1
# Out:
#          day       tempreture   windspeed  event
# 0 2017-01-01              32           6    rain
# 1 2017-01-02              28           7   sunny
# 2 2017-01-03              28            7   snow
# 3 2017-01-04               32           7   rain
# 4 2017-01-05               32           2   rain
# 5 2017-01-06               31           2  sunny
# 6 2017-01-07               34           5    NaN

# %%
list=[[1,2,3],[3,4,np.nan],[5,6,np.nan],[np.nan,np.nan,np.nan]]
df=pd.DataFrame(list)
df
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  3.0  4.0  NaN
# 2  5.0  6.0  NaN
# 3  NaN  NaN  NaN

# %%
df.dropna()
# Out:
#      0    1    2
# 0  1.0  2.0  3.0

# %% [markdown]
# group by-this method allows you to group your data and execute function on these group

# %%
import pandas as pd
df=pd.read_excel('C:\\Users\\dell\\Downloads//book2.xlsx','Sheet7')
df
# Out:
#           town  windspeed    tempreture       event  event.1
# 0     ahmdabad         6.0           56   56  sunny    sunny
# 1     ahmdabad         4.0           67   67  rainy    rainy
# 2     ahmdabad         3.0           45   45   cold     cold
# 3     ahmdabad         8.0           78   78  sunny    sunny
# 4   california         4.0           87  87   rainy    rainy
# 5   california         6.0           65  65    cold     cold
# 6   california         7.0           54  54  cloudy   cloudy
# 7   california         9.0           39  39   humid    humid
# 8       mumbai         8.0           89  89   sunny    sunny
# 9       mumbai         7.0           79  79    cold     cold
# 10      mumbai         6.5           65  65  winter   winter
# 11      mumbai         3.0           54  54  summer   summer

# %%
df1=df.drop(columns=['event'])
df2=df1.rename(columns = {'event.1':'event'})

df2.head()
df2.info()
df2
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   town         12 non-null     object
#  1   windspeed    12 non-null     float64
#  2    tempreture  12 non-null     int64
#  3   event        12 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 512.0+ bytes
#           town  windspeed    tempreture    event
# 0     ahmdabad         6.0           56    sunny
# 1     ahmdabad         4.0           67    rainy
# 2     ahmdabad         3.0           45     cold
# 3     ahmdabad         8.0           78    sunny
# 4   california         4.0           87    rainy
# 5   california         6.0           65     cold
# 6   california         7.0           54   cloudy
# 7   california         9.0           39    humid
# 8       mumbai         8.0           89    sunny
# 9       mumbai         7.0           79     cold
# ...

# %%
from pandas.core.groupby.grouper import get_grouper
g1=df2.groupby('town').sum()
g1
# Out:
#             windspeed    tempreture
# town
# ahmdabad          21.0          246
# california        26.0          245
# mumbai            24.5          287

# %%
g=df2.groupby('town',axis='index')
g.get_group('mumbai')
g

g1=df2.groupby('town').agg([np.sum,np.mean,np.std])
g1
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_11968\1745249773.py:5: FutureWarning: ['event'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   g1=df2.groupby('town').agg([np.sum,np.mean,np.std])
#            windspeed                    tempreture
#                   sum   mean       std         sum   mean        std
# town
# ahmdabad         21.0  5.250  2.217356         246  61.50  14.200939
# california       26.0  6.500  2.081666         245  61.25  20.205197
# mumbai           24.5  6.125  2.174665         287  71.75  15.392098

# %%
print(df2.groupby('town').filter(lambda x:len(x)>=3))
# Out:
#           town  windspeed    tempreture    event
# 0     ahmdabad         6.0           56    sunny
# 1     ahmdabad         4.0           67    rainy
# 2     ahmdabad         3.0           45     cold
# 3     ahmdabad         8.0           78    sunny
# 4   california         4.0           87    rainy
# 5   california         6.0           65     cold
# 6   california         7.0           54   cloudy
# 7   california         9.0           39    humid
# 8       mumbai         8.0           89    sunny
# 9       mumbai         7.0           79     cold
# 10      mumbai         6.5           65   winter
# 11      mumbai         3.0           54   summer

# %%
for event,group in g:
    print(event)
    print(group)
# Out:
# ahmdabad
#        town  windspeed    tempreture    event
# 0  ahmdabad         6.0           56    sunny
# 1  ahmdabad         4.0           67    rainy
# 2  ahmdabad         3.0           45     cold
# 3  ahmdabad         8.0           78    sunny
# california
#          town  windspeed    tempreture    event
# 4  california         4.0           87    rainy
# 5  california         6.0           65     cold
# 6  california         7.0           54   cloudy
# 7  california         9.0           39    humid
# mumbai
#       town  windspeed    tempreture    event
# 8   mumbai         8.0           89    sunny
# 9   mumbai         7.0           79     cold
# 10  mumbai         6.5           65   winter
# 11  mumbai         3.0           54   summer

# %%
g.sum()
g.count()
g.min()
g.max()
# Out:
#             windspeed    tempreture    event
# town
# ahmdabad           8.0           78    sunny
# california         9.0           87   cloudy
# mumbai             8.0           89   winter

# %%
# %matplotlib inline
g.plot()
# Out:
# town
# ahmdabad      AxesSubplot(0.125,0.125;0.775x0.755)
# california    AxesSubplot(0.125,0.125;0.775x0.755)
# mumbai        AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
g1=df2.groupby(['town','event'])
g1.max()
# Out:
#                     windspeed    tempreture
# town       event
# ahmdabad      cold         3.0           45
#              rainy         4.0           67
#              sunny         8.0           78
# california    cold         6.0           65
#              humid         9.0           39
#              rainy         4.0           87
#             cloudy         7.0           54
# mumbai        cold         7.0           79
#              sunny         8.0           89
#             summer         3.0           54
#             winter         6.5           65

# %%
stacked=df2.stack()
stacked
df2
# Out:
#           town  windspeed    tempreture    event
# 0     ahmdabad         6.0           56    sunny
# 1     ahmdabad         4.0           67    rainy
# 2     ahmdabad         3.0           45     cold
# 3     ahmdabad         8.0           78    sunny
# 4   california         4.0           87    rainy
# 5   california         6.0           65     cold
# 6   california         7.0           54   cloudy
# 7   california         9.0           39    humid
# 8       mumbai         8.0           89    sunny
# 9       mumbai         7.0           79     cold
# 10      mumbai         6.5           65   winter
# 11      mumbai         3.0           54   summer

# %%
tables=pd.pivot_table(df2,values='tempreture',index='event',columns=['town'],aggfunc=np.sum)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [91], in <cell line: 1>()
# ----> 1 tables=pd.pivot_table(df2,values='tempreture',index='event',columns=['town'],aggfunc=np.sum)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\reshape\pivot.py:95, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      92     table = concat(pieces, keys=keys, axis=1)
#      93     return table.__finalize__(data, method="pivot_table")
# ---> 95 table = __internal_pivot_table(
#      96     data,
#      97     values,
#      98     index,
#      99     columns,
#     100     aggfunc,
#     101     fill_value,
#     102     margins,
#     103     dropna,
#     104     margins_name,
#     105     observed,
#     106     sort,
#     107 )
# ...

# %%
import pandas as pd
import panel as pn

import numpy as np
pn.extension('tabulator')
import hvplot.pandas
df=pd.read_excel('C:\\Users\\dell\\Downloads//data.xlsx',skiprows=1)
df.columns=df.iloc[0]
df=df[1:]
df1.drop(columns=["NaN"])
df.head()
