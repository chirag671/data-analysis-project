# %% [markdown]
# What does mean by exploratory data analysis (EDA)? Well, by this
# mean to see the data visually. Why do we need to see the data visually?
# Well, considering that you have 1 million observations in your dataset
# then it won’t be easy for you to understand the data just by looking at it,
# so it would be better to plot it visually. But don’t you think it’s a waste of
# time? No not at all, because understanding the data lets us understand
# the importance of features and their limitations.
# source-Python
# Machine Learning
# Case Studies
#
# eda is applied to investigate the data and summarize the key insights

# %% [markdown]
# Understanding these variable types is crucial in deciding upon the type
# of charts while doing exploratory data analysis or while deciding upon a
# suitable machine learning algorithm to be applied on our data.
#
# A continuous variable can have an infinite number of values within a given range. Unlike
# discrete variables, they are not countable
#
# A discrete variable will have finite set of values within a given range
# Ordinal variables have values that are in an order from lowest to highest or vice versa.
# These levels within ordinal variables can have unequal spacing between them
#
# Nominal variables are categorical variables with no intrinsic order;
#
# ordinal

# %% [markdown]
# Univariate Analysis
# Univariate comes from the word “uni” meaning one. This is the analysis performed on a
# single variable and thus does not account for any sort of relationship among exploratory
# variables
#
# Univariate: one variable,
# Bivariate: two variables
# We can do lots of things with univariate data:
#
# Find a central value using mean, median and mode
# Find how spread out it is using range, quartiles and standard deviation
# Make plots like Bar Graphs, Pie Charts and Histograms
#
# With bivariate data we have two sets of related data we want to compare and finding any relationships
#
# We can use Tables, Scatter Plots, Correlation, Line of Best Fit, and plain old common sense.

# %% [markdown]
# statistic
#
#
# The Normal Distribution
# Normal distribution, or in other words Gaussian distribution, is a continuous probability
# distribution that is bell shaped. The important characteristic of this distribution is that
# the mean lies at the center of this distribution with a spread (i.e., standard deviation)
# around it. The majority of the observations in normal distribution lie around the mean
# and fade off as they distance away from the mean. Some 68% of the observations lie
# within 1 standard deviation from the mean; 95% of the observations lie within 2 standard
# deviations from the mean, whereas 99.7% of the observations lie within 3 standard
# deviations from the mean. A normal distribution with a mean of zero and a standard
# deviation of 1 is referred to as a standard normal distribution. Figure 1-12 shows normal
# distribution along with confidence intervals
#
#
# mean known as average is the central value of finite set of numbers.the mean is also refred to as expection which is often defined
# np.mean,np,nanmean
#
# The mean (average) of a data set is found by adding all numbers in the data set and then dividing by the number of values in the set.
# The median is the middle value when a data set is ordered from least to greatest.
# The mode is the number that occurs most often in a data set.
#
# Mean might damage by extreme end point
#
# Outliers are values that "lie outside" the other values.
#
# They can change the mean a lot, so we can either not use them (and say so) or use the median or mode instead
# When we remove outliers we are changing the data, it is no longer "pure", so we shouldn't just get rid of the outliers without a good reason!
#
# And when we do get rid of them, we should explain what we are doing and why.
#
# calculate the median and mode when you have outliers.

# %% [markdown]
# Percentile: the value below which a percentage of data falls.
#
# Quartiles are the values that divide a list of numbers into quarters:
# Quartile 1 (Q1) can be called the 25th percentile
# Quartile 2 (Q2) can be called the 50th percentile
# Quartile 3 (Q3) can be called the 75th percentile
# Q1-Q3 inqurtile
#
# variance measure how far the date points spread out from the average value--np.var()
#
# Standard Deviation
# The Standard Deviation is a measure of how spread out numbers are.it is the square root of the Variance(measure the extent to which data varies from mean) np.std() np.nanstd()
#
# covariance- measure the joint variability of two random variable and describe relation ship between two variable
# np.cov(x,y)  if positive relationship-two variable tend to vary in same direction
#
#
# in correlation value lies between -1 to 1
# np.corrcoef(x,y)
#
# skewness and kurtosiss-understanding shape of data important to analyse outlier and help to know where data lies
# skewness is measure of asymmetry of data. data set is symmetry if it looks same to left and right of center point
# positive skewness indicate longer tail on the right side of data distribution.(here mean mode and median of distribution is positive) here mean>median>mode here skewness value would be greater than 1
#
# pearsons first coefficient=mean-mode/standard devivation(divide by s.d mean it's scale down values-1 to 1
# mode=3*median-2*mode
# pearsons second coefficient or skewness=3(mean-median)/standard deviation
#
# if skewness between -0.5 to 0.5 symme
#
# if data normally distrubuted skewness would be zero.
# if total data is 50 then left and right hand size has 25 observation.
#
# kurtosis is measure of wheather data are heavy tailed(negatvie kurtosis) low peak platykurtic or light tailed(positive kurtosis)-leptokurtic or high peak ,used to find out presence of outliers.meskurtic normal peak.in short it's a measure of peakdness
#
# skewness denote-horizontal pull on data whereas kurtosis denote vertical pull on data
#
#
# Random Variable is a set of possible values from a random experiment or random variable is a way to map the outcome of the radom process.or is a variable whose value depend on the outcome of random event.
#
# probability distribution function that describe all the possible values of sample space and corresponding probabilites that random variable can take within given range
#
# there are two types of pdf
# 1.discrete distribution-describe the random process with countable sample space.bernouli,bionomial,poission
# 2.continouse distribution-describe the random process with continuse sample space. -normal,cauchy

# %%
application of linear algebra in machine learning is dimensionality reduction using principal component analysis.
pca use for high dimensnal and correlated data for feature extraction or to transform the space of feature to space of principal component.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
import statistics

# %%
df=pd.read_csv('C:\\Users\\dell\\Downloads\\excel dash board and power query//hotel_bookings 2.csv')
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.expanding()
# Out:
# Expanding [min_periods=1,center=False,axis=0,method=single]

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df[df['hotel']=='City Hotel']
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 40060   City Hotel            0          6               2015
# 40061   City Hotel            1         88               2015
# 40062   City Hotel            1         65               2015
# 40063   City Hotel            1         92               2015
# 40064   City Hotel            1        100               2015
# ...            ...          ...        ...                ...
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 40060                July                        27
# 40061                July                        27
# 40062                July                        27
# ...

# %%
df.query('hotel=="City Hotel"')
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 40060   City Hotel            0          6               2015
# 40061   City Hotel            1         88               2015
# 40062   City Hotel            1         65               2015
# 40063   City Hotel            1         92               2015
# 40064   City Hotel            1        100               2015
# ...            ...          ...        ...                ...
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 40060                July                        27
# 40061                July                        27
# 40062                July                        27
# ...

# %%
adr=list(df['adr'])
statistics.mean(adr),statistics.median(adr),statistics.mode(adr)
# Out:
# (101.83112153446687, 94.575, 62.0)

# %%
df['adr'].plot(kind='hist',bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['adr'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.kdeplot(df['adr'],shade=True,hue=df['hotel'])
# Out:
# <AxesSubplot:xlabel='adr', ylabel='Density'>

# %%
sns.pairplot(df,vars=['adr','reservation_status_date'],hue='is_canceled')

# %%
vars=['adr','reservation_status_date']
for i in vars:
    plt.figure()
    sns.distplot(df[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 2>()
#       2 for i in vars:
#       3     plt.figure()
# ----> 4     sns.distplot(df[i])
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2636, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2633     a = x
#    2635 # Make a a 1-d float array
# -> 2636 a = np.asarray(a, float)
#    2637 if a.ndim > 1:
#    2638     a = a.squeeze()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:872, in Series.__array__(self, dtype)
#     825 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#     826     """
#     827     Return the values as a NumPy array.
#     828
#    (...)
#     870           dtype='datetime64[ns]')
# ...

# %%
vars=['adr']
for i in vars:
    plt.figure()
    sns.boxplot(data=df,x='is_canceled',y=df[i])
#'"""The top and bottom of the box are the 75th and 25th percentiles, respectively. The median is shown by the
#horizontal line in the box. The dashed lines, referred to as whiskers, extend from the top and bottom to
#indicate the range for the bulk of the data""""

# %%
df[df['adr']==76.50].count
# Out:
# <bound method DataFrame.count of                hotel  is_canceled  lead_time  arrival_date_year  \
# 1672    Resort Hotel            0        382               2015
# 1687    Resort Hotel            0        146               2015
# 2042    Resort Hotel            0         72               2015
# 4528    Resort Hotel            1         41               2016
# 6672    Resort Hotel            1        155               2016
# ...              ...          ...        ...                ...
# 108016    City Hotel            0         34               2017
# 108260    City Hotel            0         61               2017
# 108280    City Hotel            0         30               2017
# 108401    City Hotel            0         35               2017
# 108484    City Hotel            0         72               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 1672            September                        37
# 1687            September                        37
# ...

# %%
print(f"skewness:{df['adr'].skew()}")
# Out:
# skewness:1.0203322771981793

# %%
df['customer_type'].value_counts(normalize=True)
# Out:
# Transient          0.750002
# Transient-Party    0.210922
# Contract           0.034282
# Group              0.004794
# Name: customer_type, dtype: float64

# %%
plt.bar(['Transient','Contract','Transient-Party','Group'],df['customer_type'].value_counts())
plt.show()

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
for col in df.describe(include='object').columns:
    print(col)
    print(df[col].unique())
    print('-'*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# --------------------------------------------------
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# --------------------------------------------------
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# --------------------------------------------------
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.drop(['agent','company'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df1=df[['adr', 'is_canceled','hotel','market_segment','reservation_status']]
df1.head()
# Out:
#     adr  is_canceled         hotel market_segment reservation_status
# 0   0.0            0  Resort Hotel         Direct          Check-Out
# 1   0.0            0  Resort Hotel         Direct          Check-Out
# 2  75.0            0  Resort Hotel         Direct          Check-Out
# 3  75.0            0  Resort Hotel      Corporate          Check-Out
# 4  98.0            0  Resort Hotel      Online TA          Check-Out

# %%
#df1[df1.adr==df1.adr.max()]
df1[['is_canceled','hotel']][df1.adr==df1.adr.max()]
# Out:
#        is_canceled       hotel
# 48515            1  City Hotel

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (118898, 30)

# %%
np.var(df['adr'])
# Out:
# 2312.7439357853223

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118898.000000  118898.000000      118898.000000
# mean        0.371352     104.311435        2016.157656
# std         0.483168     106.903309           0.707459
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118898.000000              118898.000000
# mean                  27.166555                  15.800880
# std                   13.589971                   8.780324
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df=df[df['adr']<5000]

# %%
cancelled_perc=df['is_canceled'].value_counts(normalize=True)
print(cancelled_perc)
plt.figure(figsize=(5,4))
plt.title('reservation status count')
plt.bar(['Not canceled','canceled'],df['is_canceled'].value_counts(),edgecolor='k',width=0.7)
plt.show()
# Out:
# 0    0.628653
# 1    0.371347
# Name: is_canceled, dtype: float64

# %%
groupby_user = df.groupby('is_canceled').size()
groupby_user.plot.bar(title = 'Distribution of is_canceled')
# Out:
# <AxesSubplot:title={'center':'Distribution of is_canceled'}, xlabel='is_canceled'>

# %%
groupby_user = df.groupby(['hotel','is_canceled']).size()
groupby_user.plot.bar(title = 'Distribution of hotel')
# Out:
# <AxesSubplot:title={'center':'Distribution of hotel'}, xlabel='hotel,is_canceled'>

# %%
plt.figure(figsize=(10,6))
axl=sns.countplot(x='hotel',hue='is_canceled',data=df,palette='Blues')
legend_label,_=axl.get_legend_handles_labels()
#axl.legend(bbox_to_anchor(1,1))
plt.title('reservation status in diffrent hotel',size=20)
plt.xlabel('hotel')
plt.ylabel('no. of reservation')
plt.legend(['not cancled','cancled'])
plt.show()

# %%
resort_hotel=df[df['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.72025
# 1    0.27975
# Name: is_canceled, dtype: float64

# %%
city_hotel=df[df['hotel']=='City Hotel']
city_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.582918
# 1    0.417082
# Name: is_canceled, dtype: float64

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type',
#        'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
resort_hotel=resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel=city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(20,8))
plt.title('average daily rate in city and resort hotel',fontsize=30)
plt.plot(resort_hotel.index,resort_hotel['adr'],label='Resort Hotel')

plt.plot(city_hotel.index,city_hotel['adr'],label='City Hotel')

plt.legend(fontsize=20)
plt.show()

# %%
plt.figure(figsize=(16,8))
axl=sns.countplot(x='arrival_date_year',hue='is_canceled',data=df,palette='bright')
legend_labels,_=axl.get_legend_handles_labels()
axl.legend(bbox_to_anchor=(1,1))
plt.title('reservation status per arrival_date_year',size=20)

plt.xlabel('arrival_date_year')
plt.ylabel('number of reservation')
plt.legend(['not cancled','cancled'])
plt.show()

# %%
df['month']=df['reservation_status_date'].dt.month
plt.figure(figsize=(16,8))
axl=sns.countplot(x='month',hue='is_canceled',data=df,palette='bright')
legend_labels,_=axl.get_legend_handles_labels()
axl.legend(bbox_to_anchor=(1,1))
plt.title('reservation status per month',size=20)

plt.xlabel('month')
plt.ylabel('number of reservation')
plt.legend(['not cancled','cancled'])
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.barplot('month','adr',data=df[df['is_canceled']==1].groupby('month')[['adr']].sum().reset_index(),palette='bright')
plt.legend(fontsize=20)
plt.title('ADR per month',size=20)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
cancelled_data=df[df['is_canceled']==1]
top_10_country=cancelled_data[['country']].value_counts()[:10]
plt.figure(figsize=(16,8))
plt.pie(top_10_country,autopct='%.2f',labels=top_10_country.index)
plt.title('top 10 country with reservation cancle',size=20)
plt.show()

# %%
df['market_segment'].value_counts()
# Out:
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: market_segment, dtype: int64

# %%
df['market_segment'].value_counts(normalize=True)
# Out:
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: market_segment, dtype: float64

# %%
cancelled_df_adr=cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date',inplace=True)
non_cancelled_data=df[df['is_canceled']==0]
non_cancelled_df_adr=non_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
non_cancelled_df_adr.reset_index(inplace=True)
non_cancelled_df_adr.sort_values('reservation_status_date',inplace=True)
plt.figure(figsize=(16,8))

plt.title('average daily rate',size=20)
plt.plot(non_cancelled_df_adr['reservation_status_date'],non_cancelled_df_adr['adr'],label='non_cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label='cancelled')
plt.legend()
plt.show()

# %%
cancelled_df_adr=cancelled_df_adr[(cancelled_df_adr['reservation_status_date']>'2016')&(cancelled_df_adr['reservation_status_date']<'2017-09')]
non_cancelled_df_adr=non_cancelled_df_adr[(non_cancelled_df_adr['reservation_status_date']>'2016')&(non_cancelled_df_adr['reservation_status_date']<'2017-09')]

# %%
plt.figure(figsize=(16,8))

plt.title('average daily rate',size=20)
plt.plot(non_cancelled_df_adr['reservation_status_date'],non_cancelled_df_adr['adr'],label='non_cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'],label='cancelled')
plt.legend()
plt.show()
